# %%
# # GDrive mount (required only if being run on GDrive)
# from google.colab import drive
# drive.mount('/gdrive')

# %%
# importing dependencies

import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
##### PLEASE SET THESE CAREFULLY refer :instructions.txt

#INPUT_DIR = "/gdrive/Shareddrives/DLNN_ProjC1/output/new_data_augmentation"
#OUTPUT_DIR= "/gdrive/Shareddrives/DLNN_ProjC1/output/new_data_sampling"

# INPUT_DIR="/Users/soham/Desktop/ECE 542/Project/Proj_C/Data/Data_aug/"
# OUTPUT_DIR="/Users/soham/Desktop/ECE 542/Project/Proj_C/Data/Data_sampl/"

INPUT_DIR="/content/gdrive/MyDrive/neural_networks/project_c/Pred1/Pred1/Data_aug"
OUTPUT_DIR="/content/gdrive/MyDrive/neural_networks/project_c/Pred1/Pred1/Data_sampl"


#####


# some constants
ATTRIBUTE_NAMES = ["accel_x", "accel_y", "accel_z", "gyro_x", "gyro_y", "gyro_z", "CLASS"]
X_NAMES = ["accel_x", "accel_y", "accel_z", "gyro_x", "gyro_y", "gyro_z"]
WINDOW_SIZE = 160 #4s

# %%
# some functions to make plotting data easy

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))

        val = int(val / 1000)
        return '{p:.2f}%  ({v:d}K)'.format(p=pct,v=val)
    return my_autopct

def distribution_pie(dataset, title):
  aug_0 = np.where(dataset==0)[0].shape[0]
  aug_1 = np.where(dataset==1)[0].shape[0]
  aug_2 = np.where(dataset==2)[0].shape[0]
  aug_3 = np.where(dataset==3)[0].shape[0]

  print(aug_0, aug_1, aug_2, aug_3)
  plt.figure(figsize=(6, 6))
  plt.title(title)
  plt.pie([aug_0, aug_1, aug_2, aug_3], labels = ["zero", "one", "two", "three"],
          labeldistance= True, autopct=make_autopct([aug_0, aug_1, aug_2, aug_3]), explode = (0.1, 0.1, 0.1, 0.1))
  plt.legend()

  plt.show()

# %%
# Loading the data from the file

sessions = {}
counts_of_classes = pd.DataFrame([], columns = ["filename", "zero", "one", "two", "three"])

input_files =  sorted(os.listdir(INPUT_DIR))

for input_file in input_files:
  if ".csv" in input_file:
    print("reading:", input_file, end = "\t")
    sessions[input_file] = pd.read_csv(os.path.join(INPUT_DIR, input_file))

    value_counts = sessions[input_file].CLASS.value_counts()
    for col in range(0, 4):
      if col not in value_counts.keys():
        value_counts[float(col)] = 0

        print(col, "appended")
        print(value_counts.keys())


    
    counts_of_classes = counts_of_classes.append([{"filename": input_file,
                                                      "zero": value_counts[0],                                                      
                                                      "one": value_counts[1],
                                                      "two": value_counts[2],
                                                      "three": value_counts[3]}], 
                                                      ignore_index=True)
    print("shape:", sessions[input_file].shape)

print("data_set_loaded")
# Out:
# reading: subject_001_01_x_sync_fast.csv	shape: (34101, 7)
# reading: subject_001_01_x_sync_same.csv	shape: (103096, 7)
# reading: subject_001_01_x_sync_slow.csv	shape: (41679, 7)
# reading: subject_001_02_x_sync_fast.csv	shape: (63154, 7)
# reading: subject_001_02_x_sync_same.csv	shape: (201056, 7)
# reading: subject_001_02_x_sync_slow.csv	shape: (77189, 7)
# reading: subject_001_03_x_sync_fast.csv	shape: (38831, 7)
# reading: subject_001_03_x_sync_same.csv	shape: (132776, 7)
# reading: subject_001_03_x_sync_slow.csv	shape: (47460, 7)
# reading: subject_001_04_x_sync_fast.csv	shape: (49460, 7)
# reading: subject_001_04_x_sync_same.csv	shape: (158192, 7)
# reading: subject_001_04_x_sync_slow.csv	shape: (60451, 7)
# reading: subject_001_05_x_sync_fast.csv	shape: (53208, 7)
# reading: subject_001_05_x_sync_same.csv	shape: (177060, 7)
# reading: subject_001_05_x_sync_slow.csv	shape: (65033, 7)
# reading: subject_001_06_x_sync_fast.csv	shape: (34767, 7)
# reading: subject_001_06_x_sync_same.csv	shape: (133036, 7)
# reading: subject_001_06_x_sync_slow.csv	shape: (42494, 7)
# reading: subject_001_07_x_sync_fast.csv	shape: (28280, 7)
# reading: subject_001_07_x_sync_same.csv	1 appended
# Float64Index([3.0, 2.0, 0.0, 1.0], dtype='float64')
# shape: (79665, 7)
# reading: subject_001_07_x_sync_slow.csv	shape: (34565, 7)
# reading: subject_001_08_x_sync_fast.csv	shape: (60085, 7)
# reading: subject_001_08_x_sync_same.csv	shape: (129880, 7)
# reading: subject_001_08_x_sync_slow.csv	shape: (73438, 7)
# reading: subject_002_01_x_sync_fast.csv	shape: (50399, 7)
# reading: subject_002_01_x_sync_same.csv	shape: (176748, 7)
# reading: subject_002_01_x_sync_slow.csv	shape: (61598, 7)
# reading: subject_002_02_x_sync_fast.csv	shape: (49860, 7)
# reading: subject_002_02_x_sync_same.csv	shape: (155236, 7)
# reading: subject_002_02_x_sync_slow.csv	shape: (60941, 7)
# reading: subject_002_03_x_sync_fast.csv	shape: (43917, 7)
# reading: subject_002_03_x_sync_same.csv	shape: (145108, 7)
# reading: subject_002_03_x_sync_slow.csv	shape: (53676, 7)
# reading: subject_002_04_x_sync_fast.csv	shape: (46314, 7)
# reading: subject_002_04_x_sync_same.csv	shape: (157748, 7)
# reading: subject_002_04_x_sync_slow.csv	shape: (56607, 7)
# reading: subject_002_05_x_sync_fast.csv	shape: (38087, 7)
# reading: subject_002_05_x_sync_same.csv	shape: (120908, 7)
# reading: subject_002_05_x_sync_slow.csv	shape: (46550, 7)
# reading: subject_003_01_x_sync_fast.csv	shape: (32681, 7)
# reading: subject_003_01_x_sync_same.csv	shape: (110708, 7)
# reading: subject_003_01_x_sync_slow.csv	shape: (39944, 7)
# reading: subject_003_02_x_sync_fast.csv	shape: (42489, 7)
# reading: subject_003_02_x_sync_same.csv	shape: (161016, 7)
# reading: subject_003_02_x_sync_slow.csv	shape: (51931, 7)
# reading: subject_003_03_x_sync_fast.csv	shape: (17579, 7)
# reading: subject_003_03_x_sync_same.csv	1 appended
# Float64Index([3.0, 2.0, 0.0, 1.0], dtype='float64')
# shape: (42783, 7)
# reading: subject_003_03_x_sync_slow.csv	shape: (21486, 7)
# reading: subject_004_01_x_sync_fast.csv	shape: (30878, 7)
# reading: subject_004_01_x_sync_same.csv	shape: (104804, 7)
# reading: subject_004_01_x_sync_slow.csv	shape: (37739, 7)
# reading: subject_004_02_x_sync_fast.csv	shape: (31028, 7)
# reading: subject_004_02_x_sync_same.csv	shape: (108432, 7)
# reading: subject_004_02_x_sync_slow.csv	shape: (37923, 7)
# reading: subject_005_01_x_sync_fast.csv	shape: (50471, 7)
# reading: subject_005_01_x_sync_same.csv	shape: (186652, 7)
# reading: subject_005_01_x_sync_slow.csv	shape: (61686, 7)
# reading: subject_005_02_x_sync_fast.csv	shape: (31067, 7)
# reading: subject_005_02_x_sync_same.csv	shape: (112924, 7)
# reading: subject_005_02_x_sync_slow.csv	shape: (37970, 7)
# reading: subject_005_03_x_sync_fast.csv	shape: (40414, 7)
# reading: subject_005_03_x_sync_same.csv	shape: (148468, 7)
# reading: subject_005_03_x_sync_slow.csv	shape: (49395, 7)
# reading: subject_006_01_x_sync_fast.csv	shape: (43312, 7)
# reading: subject_006_01_x_sync_same.csv	shape: (152164, 7)
# reading: subject_006_01_x_sync_slow.csv	shape: (52937, 7)
# reading: subject_006_02_x_sync_fast.csv	shape: (53605, 7)
# reading: subject_006_02_x_sync_same.csv	shape: (196424, 7)
# reading: subject_006_02_x_sync_slow.csv	shape: (65518, 7)
# reading: subject_006_03_x_sync_fast.csv	shape: (40616, 7)
# reading: subject_006_03_x_sync_same.csv	shape: (135940, 7)
# reading: subject_006_03_x_sync_slow.csv	shape: (49641, 7)
# reading: subject_007_01_x_sync_fast.csv	shape: (41580, 7)
# reading: subject_007_01_x_sync_same.csv	shape: (126660, 7)
# reading: subject_007_01_x_sync_slow.csv	shape: (50821, 7)
# reading: subject_007_02_x_sync_fast.csv	shape: (42290, 7)
# reading: subject_007_02_x_sync_same.csv	shape: (135140, 7)
# reading: subject_007_02_x_sync_slow.csv	shape: (51687, 7)
# reading: subject_007_03_x_sync_fast.csv	shape: (40176, 7)
# reading: subject_007_03_x_sync_same.csv	shape: (114852, 7)
# reading: subject_007_03_x_sync_slow.csv	shape: (49105, 7)
# reading: subject_007_04_x_sync_fast.csv	shape: (35495, 7)
# reading: subject_007_04_x_sync_same.csv	shape: (121148, 7)
# reading: subject_007_04_x_sync_slow.csv	shape: (43382, 7)
# reading: subject_008_01_x_sync_fast.csv	shape: (43324, 7)
# reading: subject_008_01_x_sync_same.csv	shape: (158264, 7)
# reading: subject_008_01_x_sync_slow.csv	shape: (52951, 7)
# data_set_loaded

# %%
# checking representation of classes in the loaded data-set
print(counts_of_classes.zero.sum(), counts_of_classes.one.sum(),
counts_of_classes.two.sum(), counts_of_classes.three.sum())
# Out:
# 3020190 1077373 1153094 1419496

# %%
# sample the train_set

random.seed("DLNN-G33")



 
aug_set = np.zeros(shape = (1, WINDOW_SIZE, 7), dtype=np.float64)

# dropping 70% of the frames that only have 0s
DROPPING_PROBABILITY_FOR_0 = 0.70

# atleast 10% of rows should be of a particular class for us to associate that frame with that class
MINIMIUM_REPRESENTATION_FOR_PRESENCE = 10

# when adding copies of the same frame, we add a random noise (upto 15%) to each frame 
NOISE_PERCENT = 15

# this is the resistance offered to the sliding window if a particular class is encountered
RESISTANCE_WINDOW_FACTOR_FOR_1 = 3.5
RESISTANCE_WINDOW_FACTOR_FOR_2 = 3.6
RESISTANCE_WINDOW_FACTOR_FOR_3 = 1.5
        

# over-sampling     
for input_file in sessions.keys():
  temp_df = sessions[input_file]
  total_samples = temp_df.shape[0]
  pointer = 0
  print("Processing: ",input_file)
  print("Sample in this file:",  total_samples)
  while(pointer + WINDOW_SIZE < total_samples):
    
    candidate_sequence = temp_df.iloc[pointer: pointer+WINDOW_SIZE]
    
    value_counts = candidate_sequence.CLASS.value_counts()
    classes_present = value_counts.keys()



    candidate_sequence = np.array(candidate_sequence)

    candidate_sequence = np.expand_dims(candidate_sequence, 0)
    if 1 in classes_present:
      if value_counts[1] > WINDOW_SIZE//MINIMIUM_REPRESENTATION_FOR_PRESENCE:
        aug_set = np.append(aug_set, candidate_sequence,  axis=0)
        noise = 1 + (np.random.rand(candidate_sequence.shape[0], WINDOW_SIZE, 6) - 0.5) * (NOISE_PERCENT*2 / 100)
        candidate_sequence[..., :6] = np.multiply(candidate_sequence[..., :6], noise)
        aug_set = np.append(aug_set, candidate_sequence,  axis=0)
        
      pointer += int(WINDOW_SIZE // RESISTANCE_WINDOW_FACTOR_FOR_1)
      

    elif 2 in classes_present:
      if value_counts[2] > WINDOW_SIZE//MINIMIUM_REPRESENTATION_FOR_PRESENCE:
        aug_set = np.append(aug_set, candidate_sequence, axis=0)
        noise = 1 + (np.random.rand(candidate_sequence.shape[0], WINDOW_SIZE, 6) - 0.5) * (NOISE_PERCENT*2 / 100)
        candidate_sequence[..., :6] = np.multiply(candidate_sequence[..., :6], noise)        
        aug_set = np.append(aug_set, candidate_sequence, axis=0)
        
      pointer += int(WINDOW_SIZE // RESISTANCE_WINDOW_FACTOR_FOR_2)

    elif 3 in classes_present:
      if value_counts[3] > WINDOW_SIZE//MINIMIUM_REPRESENTATION_FOR_PRESENCE:
        aug_set = np.append(aug_set, candidate_sequence, axis=0)
        noise = 1 + (np.random.rand(candidate_sequence.shape[0], WINDOW_SIZE, 6) - 0.5) * (NOISE_PERCENT*2 / 100)
        candidate_sequence[..., :6] = np.multiply(candidate_sequence[..., :6], noise)
        aug_set = np.append(aug_set, candidate_sequence, axis=0)
        
      pointer += int(WINDOW_SIZE // RESISTANCE_WINDOW_FACTOR_FOR_3)

    else:
      # drop with dropping frequency
      if random.uniform(0, 1) < DROPPING_PROBABILITY_FOR_0:
        # print("dropped")
        pointer +=WINDOW_SIZE;
        continue
      else:
        # print("not_dropped")
        aug_set = np.append(aug_set, candidate_sequence, axis=0)
        pointer +=WINDOW_SIZE;
        continue
  print("DONE")
  
  
aug_set = aug_set[1:]
# Out:
# Processing:  subject_001_01_x_sync_fast.csv
# Sample in this file: 34101
# DONE
# Processing:  subject_001_01_x_sync_same.csv
# Sample in this file: 103096
# DONE
# Processing:  subject_001_01_x_sync_slow.csv
# Sample in this file: 41679
# DONE
# Processing:  subject_001_02_x_sync_fast.csv
# Sample in this file: 63154
# DONE
# Processing:  subject_001_02_x_sync_same.csv
# Sample in this file: 201056
# DONE
# Processing:  subject_001_02_x_sync_slow.csv
# Sample in this file: 77189
# DONE
# Processing:  subject_001_03_x_sync_fast.csv
# Sample in this file: 38831
# DONE
# Processing:  subject_001_03_x_sync_same.csv
# Sample in this file: 132776
# DONE
# Processing:  subject_001_03_x_sync_slow.csv
# Sample in this file: 47460
# DONE
# Processing:  subject_001_04_x_sync_fast.csv
# Sample in this file: 49460
# DONE
# Processing:  subject_001_04_x_sync_same.csv
# Sample in this file: 158192
# DONE
# Processing:  subject_001_04_x_sync_slow.csv
# Sample in this file: 60451
# DONE
# Processing:  subject_001_05_x_sync_fast.csv
# Sample in this file: 53208
# DONE
# Processing:  subject_001_05_x_sync_same.csv
# Sample in this file: 177060
# DONE
# Processing:  subject_001_05_x_sync_slow.csv
# Sample in this file: 65033
# DONE
# Processing:  subject_001_06_x_sync_fast.csv
# Sample in this file: 34767
# DONE
# Processing:  subject_001_06_x_sync_same.csv
# Sample in this file: 133036
# DONE
# Processing:  subject_001_06_x_sync_slow.csv
# Sample in this file: 42494
# DONE
# Processing:  subject_001_07_x_sync_fast.csv
# Sample in this file: 28280
# DONE
# Processing:  subject_001_07_x_sync_same.csv
# Sample in this file: 79665
# DONE
# Processing:  subject_001_07_x_sync_slow.csv
# Sample in this file: 34565
# DONE
# Processing:  subject_001_08_x_sync_fast.csv
# Sample in this file: 60085
# DONE
# Processing:  subject_001_08_x_sync_same.csv
# Sample in this file: 129880
# DONE
# Processing:  subject_001_08_x_sync_slow.csv
# Sample in this file: 73438
# DONE
# Processing:  subject_002_01_x_sync_fast.csv
# Sample in this file: 50399
# DONE
# Processing:  subject_002_01_x_sync_same.csv
# Sample in this file: 176748
# DONE
# Processing:  subject_002_01_x_sync_slow.csv
# Sample in this file: 61598
# DONE
# Processing:  subject_002_02_x_sync_fast.csv
# Sample in this file: 49860
# DONE
# Processing:  subject_002_02_x_sync_same.csv
# Sample in this file: 155236
# DONE
# Processing:  subject_002_02_x_sync_slow.csv
# Sample in this file: 60941
# DONE
# Processing:  subject_002_03_x_sync_fast.csv
# Sample in this file: 43917
# DONE
# Processing:  subject_002_03_x_sync_same.csv
# Sample in this file: 145108
# DONE
# Processing:  subject_002_03_x_sync_slow.csv
# Sample in this file: 53676
# DONE
# Processing:  subject_002_04_x_sync_fast.csv
# Sample in this file: 46314
# DONE
# Processing:  subject_002_04_x_sync_same.csv
# Sample in this file: 157748
# DONE
# Processing:  subject_002_04_x_sync_slow.csv
# Sample in this file: 56607
# DONE
# Processing:  subject_002_05_x_sync_fast.csv
# Sample in this file: 38087
# DONE
# Processing:  subject_002_05_x_sync_same.csv
# Sample in this file: 120908
# DONE
# Processing:  subject_002_05_x_sync_slow.csv
# Sample in this file: 46550
# DONE
# Processing:  subject_003_01_x_sync_fast.csv
# Sample in this file: 32681
# DONE
# Processing:  subject_003_01_x_sync_same.csv
# Sample in this file: 110708
# DONE
# Processing:  subject_003_01_x_sync_slow.csv
# Sample in this file: 39944
# DONE
# Processing:  subject_003_02_x_sync_fast.csv
# Sample in this file: 42489
# DONE
# Processing:  subject_003_02_x_sync_same.csv
# Sample in this file: 161016
# DONE
# Processing:  subject_003_02_x_sync_slow.csv
# Sample in this file: 51931
# DONE
# Processing:  subject_003_03_x_sync_fast.csv
# Sample in this file: 17579
# DONE
# Processing:  subject_003_03_x_sync_same.csv
# Sample in this file: 42783
# DONE
# Processing:  subject_003_03_x_sync_slow.csv
# Sample in this file: 21486
# DONE
# Processing:  subject_004_01_x_sync_fast.csv
# Sample in this file: 30878
# DONE
# Processing:  subject_004_01_x_sync_same.csv
# Sample in this file: 104804
# DONE
# Processing:  subject_004_01_x_sync_slow.csv
# Sample in this file: 37739
# DONE
# Processing:  subject_004_02_x_sync_fast.csv
# Sample in this file: 31028
# DONE
# Processing:  subject_004_02_x_sync_same.csv
# Sample in this file: 108432
# DONE
# Processing:  subject_004_02_x_sync_slow.csv
# Sample in this file: 37923
# DONE
# Processing:  subject_005_01_x_sync_fast.csv
# Sample in this file: 50471
# DONE
# Processing:  subject_005_01_x_sync_same.csv
# Sample in this file: 186652
# DONE
# Processing:  subject_005_01_x_sync_slow.csv
# Sample in this file: 61686
# DONE
# Processing:  subject_005_02_x_sync_fast.csv
# Sample in this file: 31067
# DONE
# Processing:  subject_005_02_x_sync_same.csv
# Sample in this file: 112924
# DONE
# Processing:  subject_005_02_x_sync_slow.csv
# Sample in this file: 37970
# DONE
# Processing:  subject_005_03_x_sync_fast.csv
# Sample in this file: 40414
# DONE
# Processing:  subject_005_03_x_sync_same.csv
# Sample in this file: 148468
# DONE
# Processing:  subject_005_03_x_sync_slow.csv
# Sample in this file: 49395
# DONE
# Processing:  subject_006_01_x_sync_fast.csv
# Sample in this file: 43312
# DONE
# Processing:  subject_006_01_x_sync_same.csv
# Sample in this file: 152164
# DONE
# Processing:  subject_006_01_x_sync_slow.csv
# Sample in this file: 52937
# DONE
# Processing:  subject_006_02_x_sync_fast.csv
# Sample in this file: 53605

# %%
# checking class repreentation in the final dataset

print(aug_set.shape)
print(np.unique(aug_set[:, :, -1].flatten(), return_counts=True))

temp = aug_set[:, :, -1].flatten()
distribution_pie(temp, "Class imbalance train_set")

# %%
# saving dataset
np.save(os.path.join(OUTPUT_DIR, "dataset.npy"), aug_set)

# %%
x_mean = np.mean(np.mean((aug_set[:, :, :6]), axis = 0), axis = 0)
x_std = np.mean(np.std((aug_set[:, :, :6]), axis = 0), axis = 0)
x_min = np.min(np.min((aug_set[:, :, :6]), axis = 0), axis = 0)
x_max = np.max(np.max((aug_set[:, :, :6]), axis = 0), axis = 0)

# %%
# saving normalization-information in file

np.save(os.path.join(OUTPUT_DIR, "x_mean.npy"), x_mean)
np.save(os.path.join(OUTPUT_DIR, "x_stddev.npy"), x_std)
np.save(os.path.join(OUTPUT_DIR, "x_min.npy"), x_min)
np.save(os.path.join(OUTPUT_DIR, "x_max.npy"), x_max)
